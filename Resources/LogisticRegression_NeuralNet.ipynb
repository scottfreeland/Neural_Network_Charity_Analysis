# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf

# Import our input dataset
diabetes_df = pd.read_csv('diabetes.csv')
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Remove diabetes outcome target from features data
y = diabetes_df.Outcome
X = diabetes_df.drop(columns="Outcome")

# Split training/test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
# Preprocess numerical data for neural network

# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the logistic regression model
log_classifier = LogisticRegression(solver="lbfgs",max_iter=200)

# Train the model
log_classifier.fit(X_train,y_train)

# Evaluate the model
y_pred = log_classifier.predict(X_test)
print(f" Logistic regression model accuracy: {accuracy_score(y_test,y_pred):.3f}")
# Out:
#  Logistic regression model accuracy: 0.729

# %%
# Define the basic neural network model
nn_model = tf.keras.models.Sequential()
nn_model.add(tf.keras.layers.Dense(units=16, activation="relu", input_dim=8))
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=50)

# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/50
# 18/18 [==============================] - 2s 4ms/step - loss: 0.8362 - accuracy: 0.4705
# Epoch 2/50
# 18/18 [==============================] - 0s 4ms/step - loss: 0.7850 - accuracy: 0.5538
# Epoch 3/50
# 18/18 [==============================] - 0s 6ms/step - loss: 0.7432 - accuracy: 0.5955
# Epoch 4/50
# 18/18 [==============================] - 0s 5ms/step - loss: 0.7075 - accuracy: 0.6233
# Epoch 5/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6793 - accuracy: 0.6337
# Epoch 6/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6554 - accuracy: 0.6354
# Epoch 7/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6344 - accuracy: 0.6493
# Epoch 8/50
# 18/18 [==============================] - 0s 4ms/step - loss: 0.6171 - accuracy: 0.6580
# Epoch 9/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6014 - accuracy: 0.6632
# Epoch 10/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5875 - accuracy: 0.6701
# Epoch 11/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5758 - accuracy: 0.6771
# Epoch 12/50
# 18/18 [==============================] - 0s 4ms/step - loss: 0.5651 - accuracy: 0.6788
# Epoch 13/50
# 18/18 [==============================] - 0s 4ms/step - loss: 0.5560 - accuracy: 0.6823
# Epoch 14/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5472 - accuracy: 0.6910
# Epoch 15/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5394 - accuracy: 0.6962
# Epoch 16/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5326 - accuracy: 0.7049
# Epoch 17/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5262 - accuracy: 0.7118
# Epoch 18/50
# 18/18 [==============================] - 0s 4ms/step - loss: 0.5206 - accuracy: 0.7135
# Epoch 19/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5152 - accuracy: 0.7101
# Epoch 20/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5099 - accuracy: 0.7049
# Epoch 21/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5053 - accuracy: 0.7205
# Epoch 22/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5006 - accuracy: 0.7344
# Epoch 23/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4964 - accuracy: 0.7431
# Epoch 24/50
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4927 - accuracy: 0.7483
# Epoch 25/50
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4891 - accuracy: 0.7500
# Epoch 26/50
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4859 - accuracy: 0.7517
# Epoch 27/50
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4827 - accuracy: 0.7552
# Epoch 28/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4796 - accuracy: 0.7587
# Epoch 29/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4768 - accuracy: 0.7656
# Epoch 30/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4741 - accuracy: 0.7639
# Epoch 31/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4715 - accuracy: 0.7708
# Epoch 32/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4695 - accuracy: 0.7726
# Epoch 33/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4669 - accuracy: 0.7760
# Epoch 34/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4651 - accuracy: 0.7743
# Epoch 35/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4629 - accuracy: 0.7726
# Epoch 36/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4612 - accuracy: 0.7726
# Epoch 37/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4593 - accuracy: 0.7760
# Epoch 38/50
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4575 - accuracy: 0.7778
# Epoch 39/50
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4562 - accuracy: 0.7760
# Epoch 40/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4540 - accuracy: 0.7778
# Epoch 41/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4527 - accuracy: 0.7795
# Epoch 42/50
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4514 - accuracy: 0.7812
# Epoch 43/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4502 - accuracy: 0.7830
# Epoch 44/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4486 - accuracy: 0.7865
# Epoch 45/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4475 - accuracy: 0.7865
# Epoch 46/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4465 - accuracy: 0.7882
# Epoch 47/50
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4457 - accuracy: 0.7899
# Epoch 48/50
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4443 - accuracy: 0.7917
# Epoch 49/50
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4433 - accuracy: 0.7917
# Epoch 50/50
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4423 - accuracy: 0.7917
# 6/6 - 1s - loss: 0.4703 - accuracy: 0.7656 - 584ms/epoch - 97ms/step
# Loss: 0.47027072310447693, Accuracy: 0.765625
